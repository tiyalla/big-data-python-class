# %% [markdown]
# # MeanShift Algorithm for Clustering

# %% [markdown]
# Meanshift is a clustering algorithm that assigns the datapoints to the clusters iteratively by shifting points towards the mode.
# The mode can be understood as the highest density of datapoints (in the region, in the context of the Meanshift).
#
# Unlike the popular K-Means algorithm, meanshift does not require specifying the number of clusters in advance. The number of
# clusters is determined by the algorithm with respect to the data. (via: Damien, PythonProgramming)

# %% [markdown]
# # Use cases

# %% [markdown]
# It has applications in the field of image processing and computer vision.

# %% [markdown]
# # Data set

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams['figure.figsize'] = (16, 9)
style.use("ggplot")

# %%
data gotten from https://github.com/mubaris/friendly-fortnight

# %%
#using the same data used for the k-mean algorithm
centers = [[1,1],[5,5],[3,10]]
data = pd.read_csv('xclara.csv')
f1 = data['V1'].values
f2 = data['V2'].values
X = np.array(list(zip(f1, f2)))
(via: Damien, choika)

# %% [markdown]
# # Algorithm, graph, discussion

# %% [markdown]
# Given a set of datapoints, the algorithm iteratively assign each datapoint towards the closest cluster centroid.
# The direction to the closest cluster centroid is determined by where most of the points nearby are at. So each iteration
# each data point will move closer to where the most points are at, which is or will lead to the cluster center.
# When the algorithm stops, each point is assigned to a cluster.

# %%
#visualize data set
plt.scatter(f1,f2, c='blue', s=7)
plt.show()

# %% [markdown]
# As we can see from the visuals, there are 3 clusters. Using Meanshift algorithm, without telling it how many clusters are in the
# data set, we want MeanShift see this data set, without knowing how many clusters there ought to be, and identify the same three
# clusters we can see are obviously clusters.

# %%
#initialize MeanShift, then we fit the dataset

# %%
ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

# %%
#print clusters centers and total number of clusters
print(cluster_centers)
n_clusters_ = len(np.unique(labels))
print("Number of estimated clusters:", n_clusters_)
# Out:
# [[ 40.60755729  59.72315337]
#  [ 69.98951882 -10.17560166]
#  [  9.55909911  10.78524216]]
# ('Number of estimated clusters:', 3)

# %%
#plot results
colors = 10*['r.','g.','b.','c.','k.','y.','m.']
for i in range(len(X)):
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)

plt.scatter(cluster_centers[:,0],cluster_centers[:,1],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()

# %%
It did it! We see three clusters and their centers.

# %% [markdown]
# # References

# %%
Class Imbalance Problem, www.chioka.in/meanshift-algorithm-for-the-rest-of-us-python/.

# %%
Python Programming Tutorials, pythonprogramming.net/hierarchical-clustering-machine-learning-python-scikit-learn/.

# %%
RJ, Damien. “The Mean Shift Clustering Algorithm.” EFavDB, efavdb.com/mean-shift/.
